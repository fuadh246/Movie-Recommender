# %%
import streamlit as st
import pickle
import pandas as pd
import requests
import time

movies_dict = pickle.load(open('../app/movies_dict.pkl', 'rb'))
movies = pd.DataFrame(movies_dict)

# %%
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkYTk3MGRlZTk4YTkxYzJjM2NhY2Q0YjliYTBlY2M0ZCIsInN1YiI6IjY1NTllOWYwZDRmZTA0MDBlMWI1MjVlMyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.kZNxZbPNG8-JNW86d3kY5Bhbnllc85i9GxQQS2QrpkQ"
}
movies_dict = {}
request_counter = 0

for movies_id in movies['movie_id']:
    url = "https://api.themoviedb.org/3/movie/{}?language=en-US".format(
        movies_id)
    response = requests.get(url, headers=headers)
    data = response.json()
    movies_dict.update({movies_id: data})
    request_counter += 1

    # Check if 38 requests have been made, then sleep for 10 seconds
    if request_counter % 38 == 0:
        print(f"Pausing for 10 seconds after {request_counter} requests.")
        time.sleep(10)
# Out:
# Pausing for 10 seconds after 38 requests.
# Pausing for 10 seconds after 76 requests.
# Pausing for 10 seconds after 114 requests.
# Pausing for 10 seconds after 152 requests.
# Pausing for 10 seconds after 190 requests.
# Pausing for 10 seconds after 228 requests.
# Pausing for 10 seconds after 266 requests.
# Pausing for 10 seconds after 304 requests.
# Pausing for 10 seconds after 342 requests.
# Pausing for 10 seconds after 380 requests.
# Pausing for 10 seconds after 418 requests.
# Pausing for 10 seconds after 456 requests.
# Pausing for 10 seconds after 494 requests.
# Pausing for 10 seconds after 532 requests.
# Pausing for 10 seconds after 570 requests.
# Pausing for 10 seconds after 608 requests.
# Pausing for 10 seconds after 646 requests.
# Pausing for 10 seconds after 684 requests.
# Pausing for 10 seconds after 722 requests.
# Pausing for 10 seconds after 760 requests.
# Pausing for 10 seconds after 798 requests.
# Pausing for 10 seconds after 836 requests.
# ...

# %%
df = pd.DataFrame(movies_dict)

# %%
df = df.transpose()
df[['id', 'backdrop_path','poster_path']]
# Out:
#         adult                     backdrop_path  \
# 19995   False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg
# 285     False  /kPcHuPYqzkSo4bmPHtH82GaeEgX.jpg
# 206647  False  /cCKU3EuiSKt6xsOI6gg5kiFgZYm.jpg
# 49026   False  /c3OHQncTAnKFhdOTX7D3LTW6son.jpg
# 49529   False  /ubNevniKd5NYo60DqYIQ29T0uyB.jpg
# ...       ...                               ...
# 9367    False  /3oSXZcnd8ALYNjcy2v8t5j0THgE.jpg
# 72766   False  /ek5Yac53PCliZVpIVRLRRSseRjr.jpg
# 231617  False  /4VjcEIuE6gk5al11S5d5ATS7BDK.jpg
# 126186  False  /y8CGiAYo2E6Ld82FvNvwRwr8937.jpg
# 25975   False  /76G299sPITuIgAwCWM71KTop3Qc.jpg
#
#                                     belongs_to_collection     budget  \
# 19995   {'id': 87096, 'name': 'Avatar Collection', 'po...  237000000
# 285     {'id': 295, 'name': 'Pirates of the Caribbean ...  300000000
# 206647  {'id': 645, 'name': 'James Bond Collection', '...  245000000
# 49026   {'id': 263, 'name': 'The Dark Knight Collectio...  250000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4800 entries, 19995 to 25975
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  4793 non-null   object
#  1   backdrop_path          4619 non-null   object
#  2   belongs_to_collection  1075 non-null   object
#  3   budget                 4793 non-null   object
#  4   genres                 4793 non-null   object
#  5   homepage               4793 non-null   object
#  6   id                     4793 non-null   object
#  7   imdb_id                4793 non-null   object
#  8   original_language      4793 non-null   object
#  9   original_title         4793 non-null   object
#  10  overview               4793 non-null   object
#  11  popularity             4793 non-null   object
#  12  poster_path            4769 non-null   object
#  13  production_companies   4793 non-null   object
# ...

# %%
df = df[['id', 'backdrop_path', 'poster_path', 'release_date', 'runtime']]

# %%
df.to_csv('movies_info.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4800 entries, 0 to 4799
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     4800 non-null   int64
#  1   id             4793 non-null   float64
#  2   backdrop_path  4619 non-null   object
#  3   poster_path    4769 non-null   object
#  4   release_date   4793 non-null   object
#  5   runtime        4793 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 225.1+ KB

# %%
df
# Out:
#       Unnamed: 0        id                     backdrop_path  \
# 0          19995   19995.0  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg
# 1            285     285.0  /kPcHuPYqzkSo4bmPHtH82GaeEgX.jpg
# 2         206647  206647.0  /cCKU3EuiSKt6xsOI6gg5kiFgZYm.jpg
# 3          49026   49026.0  /c3OHQncTAnKFhdOTX7D3LTW6son.jpg
# 4          49529   49529.0  /ubNevniKd5NYo60DqYIQ29T0uyB.jpg
# ...          ...       ...                               ...
# 4795        9367    9367.0  /3oSXZcnd8ALYNjcy2v8t5j0THgE.jpg
# 4796       72766   72766.0  /ek5Yac53PCliZVpIVRLRRSseRjr.jpg
# 4797      231617  231617.0  /4VjcEIuE6gk5al11S5d5ATS7BDK.jpg
# 4798      126186  126186.0  /y8CGiAYo2E6Ld82FvNvwRwr8937.jpg
# 4799       25975   25975.0  /76G299sPITuIgAwCWM71KTop3Qc.jpg
#
#                            poster_path release_date  runtime
# 0     /kyeqWdyUXW608qlYkRqosgbbJyK.jpg   2009-12-15    162.0
# 1     /jGWpG4YhpQwVmjyHEGkxEkeRf0S.jpg   2007-05-19    169.0
# ...
